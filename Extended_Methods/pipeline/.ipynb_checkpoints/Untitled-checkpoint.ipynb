# %%
import pandas as pd
import numpy as np

# %%
flashr_NN = pd.read_csv('/work-zfs/abattle4/heyuan/tissue_spec_eQTL_v8/revision/LL/flashr_startidx10_Loadings_pvalue.txt',
                       sep = '\t')
flashr_NN.head()
# Out:
#                                             V1            V2        V3  \
# ENSG00000118961.14 chr2_20799760  2.090172e-20  5.234750e-09  0.005647
# ENSG00000118961.14 chr2_20802968  5.211157e-14  2.229730e-03  0.033890
# ENSG00000118961.14 chr2_20805159  5.565516e-05  5.042768e-03  0.015026
# ENSG00000118961.14 chr2_20805216  7.141941e-05  4.291032e-03  0.011318
# ENSG00000118961.14 chr2_20805816  1.607401e-22  1.120445e-13  0.000052
#
#                                         V4        V5        V6        V7  \
# ENSG00000118961.14 chr2_20799760  0.862677  0.097506  0.318434  0.000007
# ENSG00000118961.14 chr2_20802968  0.505857  0.267359  0.228614  0.552104
# ENSG00000118961.14 chr2_20805159  0.775996  0.048043  0.596396  0.605535
# ENSG00000118961.14 chr2_20805216  0.705816  0.050024  0.501400  0.568501
# ENSG00000118961.14 chr2_20805816  0.097222  0.016290  0.689591  0.000001
#
#                                         V8        V9       V10    ...     \
# ...

# %%
sn_spMF = pd.read_csv('/work-zfs/abattle4/heyuan/tissue_spec_eQTL_v8/revision/LL/startidx/flashr_default/flashr_startidx10_Loadings_pvalue.txt',
                     sep = '\t')
sn_spMF.head()
# Out:
#                                             V1            V2        V3  \
# ENSG00000118961.14 chr2_20799760  9.456115e-11  1.311687e-07  0.287241
# ENSG00000118961.14 chr2_20802968  4.484011e-06  3.148578e-03  0.549765
# ENSG00000118961.14 chr2_20805159  2.888225e-02  2.310329e-02  0.968072
# ENSG00000118961.14 chr2_20805216  2.805172e-02  2.254704e-02  0.962784
# ENSG00000118961.14 chr2_20805816  1.396086e-13  3.261000e-10  0.145187
#
#                                         V4        V5        V6        V7  \
# ENSG00000118961.14 chr2_20799760  0.012573  0.943350  0.123776  0.243964
# ENSG00000118961.14 chr2_20802968  0.113909  0.838559  0.517575  0.425491
# ENSG00000118961.14 chr2_20805159  0.391938  0.723557  0.644444  0.576455
# ENSG00000118961.14 chr2_20805216  0.372037  0.692827  0.628229  0.569675
# ENSG00000118961.14 chr2_20805816  0.003588  0.797662  0.255453  0.093747
#
#                                         V8        V9       V10    ...     \
# ...

# %%
idx = np.intersect1d(np.where(sn_spMF['V1'] > 0.05)[0], np.where(flashr_NN['V1'] < 1e-10)[0])

# %%
x = sn_spMF.iloc[idx]
x[x['V1'] != -1]
# Out:
#                                          V1            V2        V3        V4  \
# ENSG00000000419.12 chr20_50178380  0.347840 -1.000000e+00  0.298093  0.371702
# ENSG00000000419.12 chr20_50362806  0.307965  1.287743e-02  0.935000  0.648934
# ENSG00000000419.12 chr20_50365114  0.293187  1.095404e-02  0.346749  0.360264
# ENSG00000000419.12 chr20_50369787  0.076596  8.313649e-03  0.241789  0.248314
# ENSG00000000419.12 chr20_50620497  0.676338  7.524942e-02  0.537470  0.737590
# ENSG00000000457.13 chr1_169877742  0.312621  7.504442e-08  0.025327  0.073218
# ENSG00000000457.13 chr1_169982267  0.090094  2.833992e-07  0.029521  0.007161
# ENSG00000000457.13 chr1_170002351  0.118166  2.288952e-07  0.026186  0.008211
# ENSG00000000457.13 chr1_170016655  0.052464  5.943979e-04  0.224420  0.130200
# ENSG00000000457.13 chr1_170027452  0.107528  2.781799e-07  0.027531  0.009110
# ENSG00000000457.13 chr1_170049135  0.070313  4.427279e-04  0.162275  0.102911
# ...

# %%
from matplotlib import pyplot as plt

# %%
x = np.array(flashr_NN['V3'])
x = x[x!=-1]
len(x)
# Out:
# 98258

# %%
y = np.array(sn_spMF['V3'])
y = y[y!=-1]
len(y)
# Out:
# 97423

# %%
plt.figure()
plt.scatter(np.sort(-np.log10(y)), np.sort(np.random.choice(np.sort(-np.log10(x)), len(y), replace = False)))
plt.plot([0,30], [0,30])
plt.show()
